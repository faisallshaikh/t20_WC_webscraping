# %%
from flask import Flask, request,render_template,jsonify
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen

# %%
url = "https://www.espncricinfo.com/"

# %%
response_website = urlopen(url)

# %%
not_readable_data = response_website.read()

# %%
not_readable_data
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v2.21/fonts/icomoon.woff?gencn3" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preconnect" href="https://wassets.hscicdn.com" crossorigin="anonymous"/><link rel="preconnect" href="https://img1.hscicdn.com" crossorigin="anonymous"/><script type="text/javascript">\n          /*! js-cookie v3.0.5 | MIT */\n          !func
# ...

# %%
read_able = bs(not_readable_data, "html.parser")

# %%
read_able
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v2.21/fonts/icomoon.woff?gencn3" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" rel="preload" type="font/woff"/><link crossorigin="anonymous" href="https://wassets.hscicdn.com" rel="preconnect"/><link crossorigin="anonymous" href="https://img1.hscicdn.com" rel="preconnect"/><script type="text/javascript">
#           /*! js-cookie v3.0.5 | MIT */
# ...

# %%
to_stats = read_able.find_all("div", {"class": "ds-popper-wrapper"})[6].a["href"]

# %%
to_stats
# Out:
# 'https://www.espncricinfo.com/records'

# %%
to_stats1 = bs(to_stats, "html.parser")
# Out:
# C:\Users\solat\AppData\Local\Temp\ipykernel_14480\570860472.py:1: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   to_stats1 = bs(to_stats, "html.parser")

# %%
# to_stats1.find_all("div", {"class":"ds-flex ds-text-title-xs ds-items-center"})

# %%
# here we are getting data from the link with which we can fetch or extract data
# using find_all and providing tag and class name
product = requests.get(to_stats1)
product.encoding  = 'utf-8'

# %%
# parsing
to_in = bs(product.text, "html.parser")

# %%
to_in

# %%
icc = to_in.find_all("a", {"class":"ds-px-3 ds-py-2 hover:ds-text-typo-primary"})[5]["href"]

# %%
t20_WC = url + icc

# %%
t_20 = bs(t20_WC, "html.parser")
t_20
# Out:
# C:\Users\solat\AppData\Local\Temp\ipykernel_14480\3009944469.py:1: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   t_20 = bs(t20_WC, "html.parser")
# https://www.espncricinfo.com//records/trophy/icc-men-s-t20-world-cup-89

# %%
# same here we are trying to get data of the link
new_link = requests.get(t_20)
new_link.encoding = 'utf-8'

# %%
new_link1 = bs(new_link.text, "html.parser")
new_link1

# %%
list_of_mtc_rslt = new_link1.find_all("li", {"class": "ds-w-full ds-flex"})
list_of_mtc_rslt
# Out:
# [<li class="ds-w-full ds-flex"><a class="ds-cursor-pointer ds-inline-flex ds-items-center ds-w-full ds-py-2 ds-text-tight-s ds-px-4 ds-bg-ui-fill ds-text-typo ds-flex ds-items-center ds-box-border hover:ds-bg-ui-fill-hover focus:ds-border focus:ds-border-ui-stroke-primary focus:ds-outline-none" href="/records/trophy/team-series-results/icc-men-s-t20-world-cup-89"><span class="ds-grow"><div class="ds-flex ds-items-center ds-justify-between">Series results<i class="icon-keyboard_arrow_right-filled ds-text-icon-primary" style="font-size:16px"></i></div></span></a></li>,
# ...

# %%
a1= new_link1.find_all("a", {"class": "ds-cursor-pointer ds-inline-flex ds-items-center ds-w-full ds-py-2 ds-text-tight-s ds-px-4 ds-bg-ui-fill ds-text-typo ds-flex ds-items-center ds-box-border hover:ds-bg-ui-fill-hover focus:ds-border focus:ds-border-ui-stroke-primary focus:ds-outline-none"})
list_of_mtc_rslt1 = a1[1]["href"]
list_of_mtc_rslt1
# Out:
# '/records/trophy/team-match-results-season/icc-men-s-t20-world-cup-89'

# %%
to_lis_of_m_rslt = url + list_of_mtc_rslt1
to_lis_of_m_rslt
# Out:
# 'https://www.espncricinfo.com//records/trophy/team-match-results-season/icc-men-s-t20-world-cup-89'

# %%
converting_to = requests.get(to_lis_of_m_rslt)
converting_to.encoding = 'utf-8'
converting_to_data = bs(converting_to.text, "html.parser")
converting_to_data
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v2.21/fonts/icomoon.woff?gencn3" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" rel="preload" type="font/woff"/><link crossorigin="anonymous" href="https://wassets.hscicdn.com" rel="preconnect"/><link crossorigin="anonymous" href="https://img1.hscicdn.com" rel="preconnect"/><script type="text/javascript">
#           /*! js-cookie v3.0.5 | MIT */
# ...

# %%
converting_to_data.find_all("div", {"class":"ds-mb-6"})
# Out:
# [<div class="ds-mb-6"><div class="ds-text-title-subtle-m ds-font-medium ds-mb-1">2000s</div><a class="ds-inline-flex ds-items-start ds-leading-none" href="/records/season/team-match-results/2007to08-2007to08?trophy=89" title="2007/08"><span class="ds-text-tight-m ds-font-regular ds-text-typo hover:ds-text-typo-primary ds-block ds-mr-2 ds-pr-2 ds-border-line ds-border-r">2007/08</span></a><a class="ds-inline-flex ds-items-start ds-leading-none" href="/records/season/team-match-results/2009-2009?trophy=89" title="2009"><span class="ds-text-tight-m ds-font-regular ds-text-typo hover:ds-text-typo-primary ds-block ds-mr-2 ds-pr-2">2009</span></a></div>,
# ...

# %%
reached = converting_to_data.find_all("a", {"class":"ds-inline-flex ds-items-start ds-leading-none"})[7]['href']

# %%
to_matches = url + reached
to_matches # have to convert to pd
# Out:
# 'https://www.espncricinfo.com//records/season/team-match-results/2022to23-2022to23?trophy=89'

# %%
s = pd.read_html(to_matches)
d = s[0]
df1 = pd.DataFrame(d)
df1
# Out:
#           Team 1        Team 2        Winner      Margin     Ground  \
# 0        Namibia     Sri Lanka       Namibia     55 runs    Geelong
# 1    Netherlands        U.A.E.   Netherlands   3 wickets    Geelong
# 2       Scotland   West Indies      Scotland     42 runs     Hobart
# 3        Ireland      Zimbabwe      Zimbabwe     31 runs     Hobart
# 4        Namibia   Netherlands   Netherlands   5 wickets    Geelong
# 5      Sri Lanka        U.A.E.     Sri Lanka     79 runs    Geelong
# 6        Ireland      Scotland       Ireland   6 wickets     Hobart
# 7    West Indies      Zimbabwe   West Indies     31 runs     Hobart
# 8    Netherlands     Sri Lanka     Sri Lanka     16 runs    Geelong
# 9        Namibia        U.A.E.        U.A.E.      7 runs    Geelong
# 10       Ireland   West Indies       Ireland   9 wickets     Hobart
# 11      Scotland      Zimbabwe      Zimbabwe   5 wickets     Hobart
# 12     Australia   New Zealand   New Zealand     89 runs     Sydney
# ...

# %%
conv_to = requests.get(to_matches)
conv_to.encoding = 'utf-8'
conv_to_data = bs(conv_to.text, "html.parser")
conv_to_data
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v2.21/fonts/icomoon.woff?gencn3" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" rel="preload" type="font/woff"/><link crossorigin="anonymous" href="https://wassets.hscicdn.com" rel="preconnect"/><link crossorigin="anonymous" href="https://img1.hscicdn.com" rel="preconnect"/><script type="text/javascript">
#           /*! js-cookie v3.0.5 | MIT */
# ...

# %%
conv_to_data.find_all("span", {"class":""})

# %%
score_c = conv_to_data.find_all("a", {"class": "ds-inline-flex ds-items-start ds-leading-none"})[1]["href"]

# %%
final_score_card = url + score_c
final_score_card
# Out:
# 'https://www.espncricinfo.com//series/icc-men-s-t20-world-cup-2022-23-1298134/namibia-vs-sri-lanka-1st-match-first-round-group-a-1298135/full-scorecard'

# %%
import json
import csv

# %%
# with open("testingfile.txt", "w") as f:
#     data = csv.writer(f)
#     data.writerows(final_score_card)

# %%
rd = pd.read_html(final_score_card)
len(rd)
dataf1 = pd.DataFrame(rd[0])
dataf1.to_json("filejson")

# %%
table = conv_to_data.find_all("div", {"class": "ds-overflow-x-auto ds-scrollbar-hide"})

# %%
l = []
for k in conv_to_data.find_all("td"):
    title = k.text
    l.append(title)

l
# Out:
# ['Team 1',
#  'Team 2',
#  'Winner',
#  'Margin',
#  'Ground',
#  'Match Date',
#  'Scorecard',
#  'Namibia',
#  'Sri Lanka',
#  'Namibia',
#  '55 runs',
#  'Geelong',
#  'Oct 16, 2022',
#  'T20I # 1823',
#  'Netherlands',
#  'U.A.E.',
#  'Netherlands',
#  '3 wickets',
#  'Geelong',
#  'Oct 16, 2022',
#  'T20I # 1825',
#  'Scotland',
#  'West Indies',
#  'Scotland',
#  '42 runs',
#  'Hobart',
#  'Oct 17, 2022',
#  'T20I # 1826',
#  'Ireland',
#  'Zimbabwe',
#  'Zimbabwe',
#  '31 runs',
#  'Hobart',
#  'Oct 17, 2022',
#  'T20I # 1828',
#  'Namibia',
#  'Netherlands',
#  'Netherlands',
#  '5 wickets',
#  'Geelong',
#  'Oct 18, 2022',
#  'T20I # 1830',
#  'Sri Lanka',
#  'U.A.E.',
#  'Sri Lanka',
#  '79 runs',
#  'Geelong',
#  'Oct 18, 2022',
#  'T20I # 1832',
#  'Ireland',
#  'Scotland',
#  'Ireland',
#  '6 wickets',
#  'Hobart',
#  'Oct 19, 2022',
#  'T20I # 1833',
#  'West Indies',
#  'Zimbabwe',
#  'West Indies',
#  '31 runs',
#  'Hobart',
#  'Oct 19, 2022',
#  'T20I # 1834',
# ...

# %%
lst = []
headers = conv_to_data.find_all("thead", {"class": "ds-bg-fill-content-alternate ds-text-left"})[0]
for i in headers:
    title = i.text
    lst.append(title)

print(lst,end=" ")
print(len(lst))
# Out:
# ['Team 1Team 2WinnerMarginGroundMatch DateScorecard'] 1

# %%
url22 = requests.get(final_score_card)
url22.encoding = 'utf-8'
f_url = bs(url22.text, "html.parser")

f_url.find_all("thead", {"class": "ds-bg-fill-content-alternate ds-text-left"})
# Out:
# [<thead class="ds-bg-fill-content-alternate ds-text-left"><tr class="ds-text-right"><th class="ds-w-0 ds-whitespace-nowrap ds-min-w-max ds-text-left">BATTING</th><th class="ds-min-w-max"> </th><th class="ds-w-0 ds-whitespace-nowrap ds-min-w-max">R</th><th class="ds-w-0 ds-whitespace-nowrap ds-min-w-max">B</th><th class="ds-w-0 ds-whitespace-nowrap ds-min-w-max">M</th><th class="ds-w-0 ds-whitespace-nowrap ds-min-w-max">4s</th><th class="ds-w-0 ds-whitespace-nowrap ds-min-w-max">6s</th><th class="ds-w-0 ds-whitespace-nowrap ds-min-w-max">SR</th></tr></thead>,
# ...

# %%
a = f_url.find_all("th", {"class":"ds-min-w-max ds-text-left ds-border-r ds-border-line"})
# m = []
# for i in a:
#     title = i.text
#     m.append(title)
a
# m
# Out:
# [<th class="ds-min-w-max ds-text-left ds-border-r ds-border-line">PLAYER NAME</th>,
#  <th class="ds-min-w-max ds-text-left ds-border-r ds-border-line">TEAM</th>,
#  <th class="ds-min-w-max ds-text-left ds-border-r ds-border-line">TEAM</th>,
#  <th class="ds-min-w-max ds-text-left ds-border-r ds-border-line">TEAM</th>,
#  <th class="ds-min-w-max ds-text-left ds-border-r ds-border-line">TEAM</th>]

# %%
score_c = conv_to_data.find_all("a", {"class": "ds-inline-flex ds-items-start ds-leading-none"})
list_of_url = []
# list of url includes urls which has ground info in it...but we dont need that
for i in range(len(score_c)):
    score = url + score_c[i]["href"]
    list_of_url.append(score)

print(len(list_of_url))
only_score_card = []
s = 1
while s <= len(list_of_url)-2:
    only_score_card.append(list_of_url[s])
    s += 2

len(only_score_card)

# getting only scorecard urls
# Out:
# 89
# 44

# %%
# removing last 2 elements from list as it is not scorecard
k = 2
a= only_score_card[: len(only_score_card) - k]
len(a)
# Out:
# 42

# %%
final_list = a

# %%
(final_list)
# Out:
# ['https://www.espncricinfo.com//series/icc-men-s-t20-world-cup-2022-23-1298134/namibia-vs-sri-lanka-1st-match-first-round-group-a-1298135/full-scorecard',
#  'https://www.espncricinfo.com//series/icc-men-s-t20-world-cup-2022-23-1298134/netherlands-vs-united-arab-emirates-2nd-match-first-round-group-a-1298136/full-scorecard',
#  'https://www.espncricinfo.com//series/icc-men-s-t20-world-cup-2022-23-1298134/scotland-vs-west-indies-3rd-match-first-round-group-b-1298137/full-scorecard',
#  'https://www.espncricinfo.com//series/icc-men-s-t20-world-cup-2022-23-1298134/ireland-vs-zimbabwe-4th-match-first-round-group-b-1298138/full-scorecard',
#  'https://www.espncricinfo.com//series/icc-men-s-t20-world-cup-2022-23-1298134/namibia-vs-netherlands-5th-match-first-round-group-a-1298139/full-scorecard',
#  'https://www.espncricinfo.com//series/icc-men-s-t20-world-cup-2022-23-1298134/sri-lanka-vs-united-arab-emirates-6th-match-first-round-group-a-1298140/full-scorecard',
# ...

# %%
sw = f_url.find_all("thead")[0].text
sw
# for x in sw:
#     print(x, end=" ")
# Out:
# 'BATTING\xa0RBM4s6sSR'

# %%
sw = f_url.find_all("table")[0].text
with open("info.txt", 'w') as f:
    write = csv.writer(f)
    write.writerows(sw)

# %%
con = []
for link in final_list:
    d = pd.read_html(link)
    df_batting = pd.concat([d[0], d[2]])
    con.append(df_batting)

con[0]
# type(d[0])
# Out:
#                                               BATTING  \
# 0                                  Michael van Lingen
# 1                                                 NaN
# 2                                       Divan la Cock
# 3                                                 NaN
# 4                              Jan Nicol Loftie-Eaton
# 5                                                 NaN
# 6                                       Stephan Baard
# 7                                                 NaN
# 8                                 Gerhard Erasmus (c)
# 9                                                 NaN
# 10                                       Jan Frylinck
# 11                                                NaN
# 12                                        David Wiese
# 13                                                NaN
# 14                                            JJ Smit
# 15                                             Extras
# ...

# %%
# a = 0
# for i in range(0, len(con), 2):
#     pd.concat(con[[i], con[a+1]])
#     a = a + 2

len(con)
# Out:
# 42

# %%
# import webbrowser
# webbrowser.open(final_score_card)
# Out:
# True
